# %%
import pandas as pd
arrest = pd.read_csv("arrest_data.csv", sep=",")

# %%
arrest_dict = dict()
for index, row in arrest.iterrows():
    neighborhood_a = row['INCIDENTNEIGHBORHOOD']
    if neighborhood_a not in arrest_dict:
        arrest_dict[neighborhood_a] = 1
    else:
        arrest_dict[neighborhood_a] = arrest_dict[neighborhood_a] + 1
arrest_dict
# Out:
# {'Bloomfield': 930,
#  'Outside City': 298,
#  'Westwood': 209,
#  'East Allegheny': 2014,
#  'Crafton Heights': 546,
#  'Greenfield': 497,
#  'Brookline': 1268,
#  'Regent Square': 35,
#  'East Liberty': 1733,
#  nan: 2326,
#  'East Hills': 1084,
#  'Carrick': 2199,
#  'Allegheny Center': 1181,
#  'South Side Flats': 3186,
#  'Sheraden': 1192,
#  'East Carnegie': 48,
#  'Golden Triangle/Civic Arena': 83,
#  'Point Breeze North': 261,
#  'Perry South': 990,
#  'Allentown': 884,
#  'North Shore': 759,
#  'Marshall-Shadeland': 1406,
#  'Central Oakland': 488,
#  'Middle Hill': 880,
#  'Strip District': 472,
#  'Lincoln-Lemington-Belmar': 1219,
#  'Central Northside': 23,
#  'Troy Hill-Herrs Island': 6,
#  'Highland Park': 530,
#  'Homewood North': 1837,
#  'Northview Heights': 662,
#  'Brighton Heights': 1025,
#  'Hazelwood': 1287,
#  'Perry North': 567,
#  'Bedford Dwellings': 616,
#  'Elliott': 619,
#  'Beechview': 1116,
#  'Fineview': 773,
#  'Glen Hazel': 153,
#  'Spring Hill-City View': 667,
#  'Bluff': 1371,
#  'Manchester': 445,
#  'Homewood West': 732,
#  'Outside County': 52,
#  'Point Breeze': 287,
#  'Homewood South': 1941,
#  'Squirrel Hill South': 771,
#  'Terrace Village': 271,
#  'Upper Lawrenceville': 174,
#  'Arlington': 277,
#  'South Side Slopes': 752,
#  'Lower Lawrenceville': 249,
#  'Garfield': 661,
#  'Lincoln Place': 206,
#  'Larimer': 811,
#  'Mount Washington': 1356,
#  'California-Kirkbride': 280,
#  'Banksville': 272,
#  'Bon Air': 249,
#  'South Shore': 281,
#  'Beltzhoover': 481,
#  'Knoxville': 1240,
#  'Chateau': 415,
#  'Crawford-Roberts': 768,
#  'Polish Hill': 153,
#  'Fairywood': 112,
#  'West End': 266,
#  'Shadyside': 898,
#  'Morningside': 180,
#  'Overbrook': 294,
#  'Friendship': 157,
#  'North Oakland': 409,
#  'Central Lawrenceville': 415,
#  'Oakwood': 79,
#  'Upper Hill': 341,
#  'South Oakland': 324,
#  'West Oakland': 284,
#  'Spring Garden': 205,
#  'Allegheny West': 122,
#  'St. Clair': 48,
#  'Stanton Heights': 210,
#  'Esplen': 192,
#  'Squirrel Hill North': 270,
#  'Mt. Oliver Neighborhood': 2,
#  'Summer Hill': 67,
#  'Arlington Heights': 139,
#  'Troy Hill': 401,
#  'Central Business District': 3785,
#  'Central North Side': 783,
#  'Mount Oliver': 113,
#  'Windgap': 115,
#  'Outside State': 60,
#  'Duquesne Heights': 181,
#  'New Homestead': 39,
#  'Ridgemont': 35,
#  'Swisshelm Park': 40,
#  'Hays': 106,
#  'Chartiers City': 40,
#  'Mt. Oliver Boro': 18}

# %%
census = pd.read_csv("population-density.csv", sep=",")

# %%
census_dict = dict()
for index, row in census.iterrows():
    neighborhood_c = row['Neighborhood']
    if neighborhood_c not in census_dict:
        val = row['Pop. 2010']
        val = val.replace(',', '')
        census_dict[neighborhood_c] = int(val)
census_dict
# Out:
# {'Allegheny Center': 933,
#  'Allegheny West': 462,
#  'Allentown': 2500,
#  'Arlington': 1869,
#  'Arlington Heights': 244,
#  'Banksville': 4144,
#  'Bedford Dwellings': 1202,
#  'Beechview': 7974,
#  'Beltzhoover': 1925,
#  'Bloomfield': 8442,
#  'Bluff': 6600,
#  'Bon Air': 808,
#  'Brighton Heights': 7247,
#  'Brookline': 13214,
#  'California-Kirkbride': 761,
#  'Carrick': 10113,
#  'Central Business District': 3629,
#  'Central Lawrenceville': 4482,
#  'Central Northside': 2923,
#  'Central Oakland': 6086,
#  'Chartiers City': 477,
#  'Chateau': 11,
#  'Crafton Heights': 3814,
#  'Crawford-Roberts': 2256,
#  'Duquesne Heights': 2425,
#  'East Allegheny': 2136,
#  'East Carnegie': 570,
#  'East Hills': 3169,
#  'East Liberty': 5869,
#  'Elliott': 2381,
#  'Esplen': 301,
#  'Fairywood': 1002,
#  'Fineview': 1285,
#  'Friendship': 1785,
#  'Garfield': 3675,
#  'Glen Hazel': 716,
#  'Greenfield': 7294,
#  'Hays': 362,
#  'Hazelwood': 4317,
#  'Highland Park': 6395,
#  'Homewood North': 3280,
#  'Homewood South': 2344,
#  'Homewood West': 818,
#  'Knoxville': 3747,
#  'Larimer': 1728,
#  'Lincoln Place': 3227,
#  'Lincoln-Lemington-Belmar': 4883,
#  'Lower Lawrenceville': 2341,
#  'Manchester': 2130,
#  'Marshall-Shadeland': 6043,
#  'Middle Hill': 1707,
#  'Morningside': 3346,
#  'Mount Washington': 8799,
#  'Mt. Oliver': 509,
#  'New Homestead': 990,
#  'North Oakland': 10551,
#  'North Shore': 303,
#  'Northview Heights': 1214,
#  'Oakwood': 1027,
#  'Overbrook': 3644,
#  'Perry North': 4050,
#  'Perry South': 4145,
#  'Point Breeze': 5315,
#  'Point Breeze North': 2054,
#  'Polish Hill': 1274,
#  'Regent Square': 928,
#  'Ridgemont': 483,
#  'Shadyside': 13915,
#  'Sheraden': 5299,
#  'South Oakland': 2969,
#  'South Shore': 19,
#  'South Side Flats': 6597,
#  'South Side Slopes': 4423,
#  'Spring Garden': 884,
#  'Spring Hill-City View': 2648,
#  'Squirrel Hill North': 11363,
#  'Squirrel Hill South': 15110,
#  'St. Clair': 209,
#  'Stanton Heights': 4601,
#  'Strip District': 616,
#  'Summer Hill': 1051,
#  'Swisshelm Park': 1361,
#  'Terrace Village': 3228,
#  'Troy Hill': 2714,
#  'Upper Hill': 2057,
#  'Upper Lawrenceville': 2669,
#  'West End': 254,
#  'West Oakland': 2604,
#  'Westwood': 3066,
#  'Windgap': 1369}

# %%
arrest_to_pop_ratio = dict()
for key in census_dict:
        if key in arrest_dict:
            pop = census_dict[key]
            arrests = arrest_dict[key]
            ratio = arrests/pop
            arrest_to_pop_ratio[key] = ratio
arrest_to_pop_ratio
# Out:
# {'Allegheny Center': 1.2658092175777063,
#  'Allegheny West': 0.26406926406926406,
#  'Allentown': 0.3536,
#  'Arlington': 0.14820759764579988,
#  'Arlington Heights': 0.569672131147541,
#  'Banksville': 0.06563706563706563,
#  'Bedford Dwellings': 0.5124792013311148,
#  'Beechview': 0.1399548532731377,
#  'Beltzhoover': 0.24987012987012988,
#  'Bloomfield': 0.11016346837242359,
#  'Bluff': 0.20772727272727273,
#  'Bon Air': 0.30816831683168316,
#  'Brighton Heights': 0.14143783634607424,
#  'Brookline': 0.09595883154230361,
#  'California-Kirkbride': 0.3679369250985545,
#  'Carrick': 0.21744289528329871,
#  'Central Business District': 1.042987048773767,
#  'Central Lawrenceville': 0.09259259259259259,
#  'Central Northside': 0.00786862812179268,
#  'Central Oakland': 0.0801840289188301,
#  'Chartiers City': 0.08385744234800839,
#  'Chateau': 37.72727272727273,
#  'Crafton Heights': 0.14315679077084426,
#  'Crawford-Roberts': 0.3404255319148936,
#  'Duquesne Heights': 0.07463917525773196,
#  'East Allegheny': 0.9428838951310862,
#  'East Carnegie': 0.08421052631578947,
#  'East Hills': 0.34206374250552224,
#  'East Liberty': 0.295280286249787,
#  'Elliott': 0.2599748005039899,
#  'Esplen': 0.6378737541528239,
#  'Fairywood': 0.11177644710578842,
#  'Fineview': 0.601556420233463,
#  'Friendship': 0.08795518207282914,
#  'Garfield': 0.1798639455782313,
#  'Glen Hazel': 0.21368715083798884,
#  'Greenfield': 0.06813819577735125,
#  'Hays': 0.292817679558011,
#  'Hazelwood': 0.29812369701181374,
#  'Highland Park': 0.08287724784988272,
#  'Homewood North': 0.5600609756097561,
#  'Homewood South': 0.8280716723549488,
#  'Homewood West': 0.8948655256723717,
#  'Knoxville': 0.3309314117961035,
#  'Larimer': 0.4693287037037037,
#  'Lincoln Place': 0.0638363805392005,
#  'Lincoln-Lemington-Belmar': 0.24964161376203153,
#  'Lower Lawrenceville': 0.10636480136693721,
#  'Manchester': 0.20892018779342722,
#  'Marshall-Shadeland': 0.23266589442329969,
#  'Middle Hill': 0.5155243116578794,
#  'Morningside': 0.05379557680812911,
#  'Mount Washington': 0.15410842141152403,
#  'New Homestead': 0.03939393939393939,
#  'North Oakland': 0.03876409818974505,
#  'North Shore': 2.504950495049505,
#  'Northview Heights': 0.5453047775947282,
#  'Oakwood': 0.07692307692307693,
#  'Overbrook': 0.08068057080131723,
#  'Perry North': 0.14,
#  'Perry South': 0.2388419782870929,
#  'Point Breeze': 0.053998118532455314,
#  'Point Breeze North': 0.12706913339824732,
#  'Polish Hill': 0.12009419152276295,
#  'Regent Square': 0.03771551724137931,
#  'Ridgemont': 0.07246376811594203,
#  'Shadyside': 0.06453467481135465,
#  'Sheraden': 0.22494810341573881,
#  'South Oakland': 0.10912765240821826,
#  'South Shore': 14.789473684210526,
#  'South Side Flats': 0.4829467939972715,
#  'South Side Slopes': 0.17002034817996833,
#  'Spring Garden': 0.2319004524886878,
#  'Spring Hill-City View': 0.2518882175226586,
#  'Squirrel Hill North': 0.023761330634515535,
#  'Squirrel Hill South': 0.051025810721376574,
#  'St. Clair': 0.22966507177033493,
#  'Stanton Heights': 0.04564225168441643,
#  'Strip District': 0.7662337662337663,
#  'Summer Hill': 0.06374881065651761,
#  'Swisshelm Park': 0.029390154298310066,
#  'Terrace Village': 0.08395291201982652,
#  'Troy Hill': 0.1477523949889462,
#  'Upper Hill': 0.1657754010695187,
#  'Upper Lawrenceville': 0.06519295616335706,
#  'West End': 1.047244094488189,
#  'West Oakland': 0.10906298003072197,
#  'Westwood': 0.06816699282452707,
#  'Windgap': 0.08400292184075968}

# %% [markdown]
# ## Conclusion
# ---
# After counting the number of arrests in each neighborhood, I used census data from 2010 to figure out the population of each neighborhood. If the neighborhood was included in both datasets, I found the ratio between the number of arrests and the population of each neighborhood. Whichever one of these ratios was the lowest will determine which neighborhood is the best to live in. I will list the top 5 for the sole purpose of comparing to the other submetrics that my group members have, here are the top 5 neighborhoods, from best to "worst".
# 1. Central Northside = 0.00786862812179268
# 2. Squirrel Hill North = 0.023761330634515535
# 3. Swisshelm Park = 0.029390154298310066
# 4. Regent Square = 0.03771551724137931
# 5. North Oakland = 0.03876409818974505
